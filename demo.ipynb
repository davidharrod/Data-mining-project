# %% [markdown]
# # Import dependencies

# %%
import data_utils
import model

# %% [markdown]
# # Load data

# %%
path = "./data/data.csv"
X_train, X_test, y_train, y_test = data_utils.load_data(path)

# %% [markdown]
# # Create and train model

# %%
gbdt = model.train(X_train, y_train)

# %% [markdown]
# # Predict

# %%
print(model.predict(gbdt,X_test).shape)
# Out:
# (498,)

# %% [markdown]
# # Test the trained model

# %%
model.test(gbdt, X_test, y_test)
# Out:
# 模型的准确率为：
#  0.7289156626506024
# 模型的评估报告：
#                precision    recall  f1-score   support
#
#            0       0.71      0.86      0.78       274
#            1       0.77      0.57      0.65       224
#
#     accuracy                           0.73       498
#    macro avg       0.74      0.71      0.72       498
# weighted avg       0.74      0.73      0.72       498
